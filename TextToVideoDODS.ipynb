# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan4codes/StableDiffusionModels/blob/main/TextToVideoDODS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 20.3 MB/s eta 0:00:00
# ...

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 30.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 42.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.4 MB/s eta 0:00:00
# ...

# %%
# import torch
# from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
# from diffusers.utils import export_to_video
# import gradio as gr

# # Load the DiffusionPipeline model
# pipe = DiffusionPipeline.from_pretrained("cerspense/zeroscope_v2_576w", torch_dtype=torch.float16)
# pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
# pipe.enable_model_cpu_offload()

# # Define a Gradio interface
# iface = gr.Interface(
#     fn=lambda prompt: export_to_video(pipe(prompt, num_inference_steps=40, height=320, width=576, num_frames=24).frames[0]),
#     inputs="text",
#     outputs="video",
#     live=True,
#     title="Diffusion Pipeline Video Generation",
#     description="Enter a prompt to generate a video using Diffusion Pipeline."
# )

# # Launch the Gradio interface
# iface.launch()

# %% [markdown]
# ## ali-vilab/text-to-video-ms-1.7b

# %%
import gradio as gr
import torch
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler
from diffusers.utils import export_to_video

# Initialize your DiffusionPipeline as you did in your code
pipe = DiffusionPipeline.from_pretrained("damo-vilab/text-to-video-ms-1.7b", torch_dtype=torch.float16, variant="fp16")
pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe.enable_model_cpu_offload()

# Define a Gradio function that takes a text input and generates a video
def generate_video(prompt):
    video_frames = pipe(prompt, num_inference_steps=360).frames
    video_frames = video_frames[0]
    video_path = export_to_video(video_frames)
    return video_path
prompt= input("Enter prompt")
generate_video(prompt)
# # Create a Gradio interface
# iface = gr.Interface(
#     fn=generate_video,
#     inputs="text",
#     outputs="video",
#     title="Text-to-Video Generation",
#     description="Enter a text prompt to generate a video.",
# )

# # Start the Gradio interface
# iface.launch()
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# Enter prompt Bathroom Design
#   0%|          | 0/360 [00:00<?, ?it/s]
# '/tmp/tmp2r_9ekeg.mp4'
